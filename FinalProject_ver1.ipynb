# %% [markdown]
# import numpy as np
# import torchaudio
# from pathlib import Path
# import matplotlib.pyplot as plt
#
#
# def analyze_waveform_lengths(root, sr=16000):
#     lengths = []
#     paths = list(Path(root).rglob("*.wav"))
#
#     for path in paths:
#         try:
#             waveform, file_sr = torchaudio.load(path)
#             if file_sr != sr:
#                 resampler = torchaudio.transforms.Resample(file_sr, sr)
#                 waveform = resampler(waveform)
#             lengths.append(waveform.shape[1])  # 長度以 sample 為單位
#         except Exception as e:
#             print(f"⚠️ Error reading {path}: {e}")
#
#     return lengths
#
#
# train_lengths = analyze_waveform_lengths("Data/Train/")
# test_lengths = analyze_waveform_lengths("Data/Test/")
# train_lengths_np = np.array(train_lengths)
# print("Train Waveform analyze compelete")
# test_lengths_np = np.array(test_lengths)
# print("Test Waveform analyze compelete")
#
# print("📊 Train Waveform 長度統計:")
# print(f"最大值: {train_lengths_np.max()}")
# print(f"最小值: {train_lengths_np.min()}")
# print(f"平均值: {train_lengths_np.mean():.2f}")
# print(f"中位數: {np.median(train_lengths_np)}")
# print(f"90 百分位數: {np.percentile(train_lengths_np, 90)}")
#
# print("📊 Test Waveform 長度統計:")
# print(f"最大值: {test_lengths_np.max()}")
# print(f"最小值: {test_lengths_np.min()}")
# print(f"平均值: {test_lengths_np.mean():.2f}")
# print(f"中位數: {np.median(test_lengths_np)}")
# print(f"90 百分位數: {np.percentile(test_lengths_np, 90)}")

# %%
target_len = 58000

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torch.nn.utils.rnn import pad_sequence
import torch.nn.functional as F
from pathlib import Path
import librosa
import numpy as np
from modelscope.pipelines import pipeline
from modelscope.models import Model
from modelscope.utils.constant import Tasks
import torchaudio



class VoiceFolder(Dataset):
    def __init__(self, root, transform=None, sr=16000,target_len=target_len):
        self.file_paths = list(Path(root).rglob("*.wav"))
        self.transform = transform
        self.sr = sr
        self.target_len = target_len
        self.labels = sorted({p.parent.name for p in self.file_paths})
        self.label2id = {label: idx for idx, label in enumerate(self.labels)}

    def __len__(self):
        return len(self.file_paths)
    
    def pad_or_trim(self, waveform):
        cur_len = waveform.shape[-1]
        if cur_len >= self.target_len:
            return waveform[..., :self.target_len]
        else:
            pad_len = self.target_len - cur_len
            return F.pad(waveform, (0, pad_len))

    def __getitem__(self, idx):
        path = self.file_paths[idx]
        try:
            waveform, file_sr = torchaudio.load(path)
            if file_sr != self.sr:
                resampler = torchaudio.transforms.Resample(orig_freq=file_sr, new_freq=self.sr)
                waveform = resampler(waveform)
            if self.transform:
                waveform = self.transform(waveform)
            waveform = waveform.float()
            max_val = waveform.abs().max()
            #if max_val > 0:
                #waveform = waveform / max_val

            waveform = self.pad_or_trim(waveform)
            label_str = path.parent.name
            label = self.label2id.get(label_str) 
            return waveform.squeeze(0), label
        except Exception as e:
            print(f"[ERROR] loading {path}: {e}")
            return torch.zeros(self.sr), -1


def simple_transform(waveform):
    waveform = waveform.float()
    waveform = waveform / waveform.abs().max()
    return waveform

def collate_fn(batch):
    waveforms, labels = zip(*batch)
    
    # 轉為 list of tensors，統一為 [batch_size, max_len]
    waveforms = [w if isinstance(w, torch.Tensor) else torch.tensor(w) for w in waveforms]
    waveforms = pad_sequence(waveforms, batch_first=True)  # padding to max length
    labels = torch.tensor(labels)
    return waveforms, labels

train_root = "Data/Train/"
test_root = "Data/Test/"  
batch_size = 32
total_epoch = 100
lr = 1e-4
weight_decay=1e-4
train_dataset = VoiceFolder(root=train_root, transform=simple_transform)
test_dataset = VoiceFolder(root=test_root, transform=simple_transform)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)
val_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)

train_labels_set = set(train_dataset.labels)
test_labels_set = set(test_dataset.labels)
print(train_labels_set)
if train_labels_set != test_labels_set:
    print("⚠️ Train and test labels do not match!")
    print("Train labels only:", train_labels_set - test_labels_set)
    print("Test labels only :", test_labels_set - train_labels_set)
else:
    print("✅ Train and test labels match exactly.")
# Out:
# {'fear', 'anger', 'sad', 'neutral', 'disgust', 'happy'}
# ✅ Train and test labels match exactly.

# %%
import contextlib
import os
from collections import Counter



device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")


feature_model = pipeline(
    task=Tasks.auto_speech_recognition, model='iic/emotion2vec_base')

num_classes = len(train_dataset.label2id)
print(num_classes, " type")
classifier = nn.Sequential(
    nn.BatchNorm1d(768),
    nn.Dropout(0.1),
    nn.Linear(768, 512),
    nn.BatchNorm1d(512),
    nn.GELU(),
    nn.Dropout(0.1),
    nn.Linear(512, 64),
    nn.BatchNorm1d(64),
    nn.GELU(),
    nn.Dropout(0.1),
    nn.Linear(64, num_classes)
).to(device)  # 768 是 Emotion2Vec 預設輸出維度
optimizer = torch.optim.Adam(classifier.parameters(), lr=lr, weight_decay=weight_decay)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.7, patience=3)

loss_fn = torch.nn.CrossEntropyLoss()


def train_epoch(epoch):
    classifier.train()
    train_loss = 0.
    correct_train = 0.
    total_train = 0.
    valid_labels = []
    count = 0
    for data in train_loader:
        waveforms, labels = data
        waveforms = waveforms.to(device)
        labels = labels.to(device)
        batch_feats = []
        temp = []
        with torch.no_grad():
            # waveforms shape: [batch_size, ...]
            for waveform, label in zip(waveforms, labels):
                with open(os.devnull, 'w') as fnull:
                    with contextlib.redirect_stderr(fnull):
                        single_output = feature_model(
                            waveform.unsqueeze(0))  # 加 batch 維度
                feats_np = single_output[0]['feats']  # 取出 list[0] 中的 'feats'
                feat_tensor = torch.from_numpy(feats_np).float()
                if torch.isnan(feat_tensor).any() or torch.isinf(feat_tensor).any():
                    # print("🚨 Detected NaN or Inf in features")
                    continue
                batch_feats.append(feat_tensor)
                temp.append(label)
        if len(batch_feats) < 2:
            continue
        features = torch.stack(batch_feats).to(
            device)  # shape: [batch_size, feat_dim]
        valid_labels += temp
        temp = torch.tensor(temp).to(device)
        outputs = classifier(features)
        loss = loss_fn(outputs, temp)
        _, predicted = torch.max(outputs, 1)
        correct_train += (predicted == temp).sum().item()
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        total_train += temp.size(0)
        # print("epoch ",epoch," trainloop ",count," finish")
        #count += 1
        #if count > 50:
            #break
    train_loss /= len(valid_labels)
    train_accuracy = correct_train / total_train

    return train_loss, train_accuracy*100


def validation(epoch):
    classifier.eval()
    correct = 0.
    total = 0.
    val_loss = 0.
    valid_labels = []
    count = 0
    all_preds = []
    all_labels = []
    with torch.no_grad():
        for data in val_loader:
            waveforms, labels = data
            waveforms = waveforms.to(device)
            labels = labels.to(device)
            batch_feats = []
            temp = []
            # waveforms shape: [batch_size, ...]
            for waveform, label in zip(waveforms, labels):
                with open(os.devnull, 'w') as fnull:
                    with contextlib.redirect_stderr(fnull):
                        single_output = feature_model(
                            waveform.unsqueeze(0))  # 加 batch 維度
                feats_np = single_output[0]['feats']  # 取出 list[0] 中的 'feats'
                feat_tensor = torch.from_numpy(feats_np).float()
                if torch.isnan(feat_tensor).any() or torch.isinf(feat_tensor).any():
                    # print("🚨 Detected NaN or Inf in features")
                    continue
                batch_feats.append(feat_tensor)
                temp.append(label)
            if len(batch_feats) < 2:
                continue
            features = torch.stack(batch_feats).to(
                device)  # shape: [batch_size, feat_dim]
            valid_labels += temp
            temp = torch.tensor(temp).to(device)
            outputs = classifier(features)
            loss = loss_fn(outputs, temp)
            val_loss += loss.item()
            _, preds = torch.max(outputs, 1)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(temp.cpu().numpy())

            correct += (preds == temp).sum().item()
            total += temp.size(0)
            # print("epoch ",epoch," testloop ",count," finish")
            #count += 1
            #if count > 50:
                #break

    val_loss /= len(valid_labels)
    val_accuracy = correct / total
    return val_loss, val_accuracy*100, all_preds, all_labels
# Out:
# Using cuda device
# 2025-06-09 06:50:53,404 - modelscope - WARNING - Model revision not specified, use revision: v2.0.4
# 2025-06-09 06:50:54,535 - modelscope - WARNING - Model revision not specified, use revision: v2.0.4
# Downloading Model from https://www.modelscope.cn to directory: C:\Users\ChiaYan\.cache\modelscope\hub\models\iic\emotion2vec_base
# 2025-06-09 06:50:54,771 - modelscope - INFO - initiate model from C:\Users\ChiaYan\.cache\modelscope\hub\models\iic\emotion2vec_base
# 2025-06-09 06:50:54,772 - modelscope - INFO - initiate model from location C:\Users\ChiaYan\.cache\modelscope\hub\models\iic\emotion2vec_base.
# 2025-06-09 06:50:54,776 - modelscope - INFO - initialize model from C:\Users\ChiaYan\.cache\modelscope\hub\models\iic\emotion2vec_base
# funasr version: 1.2.6.
# Check update of funasr, and it would cost few times. You may disable it by set `disable_update=True` in AutoModel
# You are using the latest version of funasr-1.2.6
# 2025-06-09 06:50:56,597 - modelscope - WARNING - No preprocessor field found in cfg.
# 2025-06-09 06:50:56,598 - modelscope - WARNING - No val key and type key found in preprocessor domain of configuration.json file.
# 2025-06-09 06:50:56,599 - modelscope - WARNING - Cannot find available config to build preprocessor at mode inference, current config: {'model_dir': 'C:\\Users\\ChiaYan\\.cache\\modelscope\\hub\\models\\iic\\emotion2vec_base'}. trying to build by task and model information.
# 2025-06-09 06:50:56,599 - modelscope - WARNING - No preprocessor key ('funasr', 'emotion-recognition') found in PREPROCESSOR_MAP, skip building preprocessor.
# 6  type

# %%
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt

import pandas as pd


best_val_acc = 0
patience = 5
wait = 0

train_loss = []
train_acc = []
val_loss = []
val_acc = []

print("start")

for epoch in range(total_epoch):
    tl, ta = train_epoch(epoch+1)
    vl, va, all_preds, all_labels = validation(epoch+1)
    train_loss.append(tl)
    train_acc.append(ta)
    val_loss.append(vl)
    val_acc.append(va)
    scheduler.step(vl)

    print(f"Epoch {epoch+1}  Train Loss: {train_loss[epoch]:.4f}  Train Accuracy: {train_acc[epoch]:.2f}% \
        Val Loss: {val_loss[epoch]:.4f}  Val Accuracy: {val_acc[epoch]:.2f}% ")
    cm = confusion_matrix(all_labels, all_preds)
    df_cm = pd.DataFrame(cm, index=list(train_labels_set), columns=list(train_labels_set))
    print(df_cm)

    if va > best_val_acc:
        best_val_acc = va
        wait = 0
    else:
        wait += 1
    if wait > patience:
        break
# Out:
# start
# Epoch 1  Train Loss: 0.0358  Train Accuracy: 58.88%         Val Loss: 0.0264  Val Accuracy: 71.19%
#          fear  anger   sad  neutral  disgust  happy
# fear     2021    199   118      272      119     66
# anger     113   1903   174      145      141    319
# sad        62    132  1842      199      142    418
# neutral   130    162   207     1978      222     96
# disgust    16     55    14      132     2046    112
# happy      23    263   216       96      347   1848
# Epoch 2  Train Loss: 0.0260  Train Accuracy: 70.29%         Val Loss: 0.0217  Val Accuracy: 75.19%
#          fear  anger   sad  neutral  disgust  happy
# fear     2303    118    98      153       72     51
# anger     173   1944   165       77       96    340
# sad        78     98  2047      140       96    336
# neutral   155    118   231     2055      158     78
# disgust    32     27    43      103     2003    167
# happy      50    231   274       66      232   1940
# Epoch 3  Train Loss: 0.0231  Train Accuracy: 73.19%         Val Loss: 0.0198  Val Accuracy: 76.88%
#          fear  anger   sad  neutral  disgust  happy
# fear     2343    130    54      155       64     49
# anger     157   2053   112       67       77    329
# sad        83    120  1956      165       75    396
# neutral   155    127   168     2133      136     76
# disgust    40     47    26      105     2031    126
# happy      43    233   194       58      212   2053
# Epoch 4  Train Loss: 0.0215  Train Accuracy: 74.78%         Val Loss: 0.0188  Val Accuracy: 78.02%
#          fear  anger   sad  neutral  disgust  happy
# fear     2351    110    57      150       64     63
# anger     139   2050   145       94       56    311
# sad        64     80  2064      169       59    359
# neutral   148     77   174     2183      116     97
# disgust    32     33    31       80     2029    170
# happy      29    196   253       49      189   2077
# Epoch 5  Train Loss: 0.0204  Train Accuracy: 75.81%         Val Loss: 0.0181  Val Accuracy: 78.66%
#          fear  anger   sad  neutral  disgust  happy
# fear     2381     97    43      181       48     45
# anger     150   2036   117       85       57    350
# sad        69     78  2034      181       45    388
# neutral   127     92   167     2216      108     85
# disgust    30     34    26      121     1999    165
# happy      32    168   191       55      154   2193
# Epoch 6  Train Loss: 0.0193  Train Accuracy: 77.09%         Val Loss: 0.0174  Val Accuracy: 79.76%
#          fear  anger   sad  neutral  disgust  happy
# fear     2365    111    50      177       49     43
# anger     119   2106   136       81       63    290
# sad        58     75  2133      144       52    333
# neutral   106     88   174     2265       96     66
# disgust    23     39    36      111     2042    124
# happy      23    178   223       62      179   2128
# Epoch 7  Train Loss: 0.0185  Train Accuracy: 77.90%         Val Loss: 0.0170  Val Accuracy: 79.81%
#          fear  anger   sad  neutral  disgust  happy
# fear     2357     94    60      177       63     44
# anger     130   2096   145       99       52    273
# sad        52     80  2199      153       51    260
# neutral    89     70   194     2272      115     55
# disgust    24     26    41       95     2076    113
# happy      26    175   287       61      196   2048
# Epoch 8  Train Loss: 0.0180  Train Accuracy: 78.68%         Val Loss: 0.0167  Val Accuracy: 79.96%
#          fear  anger   sad  neutral  disgust  happy
# fear     2365    134    60      137       52     47
# anger     105   2145   145       49       46    305
# sad        49     74  2129      131       60    352
# neutral   144     96   183     2191      111     70
# disgust    31     40    31       78     2067    128
# happy      19    163   229       30      177   2175
# Epoch 9  Train Loss: 0.0171  Train Accuracy: 79.63%         Val Loss: 0.0165  Val Accuracy: 80.73%
#          fear  anger   sad  neutral  disgust  happy
# fear     2407     86    62      146       63     31
# anger     134   2018   130       97       71    345
# sad        45     59  2114      177       50    350
# neutral    84     60   133     2350      100     68
# disgust    27     17    24       83     2088    136
# happy      31    104   207       59      171   2221
# Epoch 10  Train Loss: 0.0167  Train Accuracy: 80.18%         Val Loss: 0.0158  Val Accuracy: 81.15%
#          fear  anger   sad  neutral  disgust  happy
# fear     2425     69    54      164       45     38
# anger     129   2089   147       93       44    293
# sad        47     51  2204      171       41    281
# neutral    79     50   159     2359       86     62
# disgust    23     24    27      108     2067    126
# happy      26    141   296       49      158   2123
# Epoch 11  Train Loss: 0.0160  Train Accuracy: 81.03%         Val Loss: 0.0157  Val Accuracy: 81.34%
#          fear  anger   sad  neutral  disgust  happy
# fear     2461     88    25      123       72     26
# anger     121   2170    97       75       54    278
# sad        72     87  2112      142       66    316
# neutral   107     86   144     2258      136     64
# disgust    25     25    22       80     2114    109
# happy      27    163   205       36      179   2183
# Epoch 12  Train Loss: 0.0156  Train Accuracy: 81.38%         Val Loss: 0.0153  Val Accuracy: 82.00%
#          fear  anger   sad  neutral  disgust  happy
# fear     2503     80    42      103       36     31
# anger     145   2266   126       55       31    172
# sad        64    115  2245      130       37    204
# neutral   124    100   136     2305       79     51
# disgust    53     44    39       91     2042    106
# happy      32    230   296       50      140   2045
# Epoch 13  Train Loss: 0.0152  Train Accuracy: 81.83%         Val Loss: 0.0153  Val Accuracy: 81.83%
#          fear  anger   sad  neutral  disgust  happy
# fear     2491     65    40      121       46     32
# anger     139   2151   111       94       51    249
# sad        58     61  2147      168       54    307
# neutral   105     55   127     2361       92     55
# disgust    21     22    17      113     2089    113
# happy      35    160   211       63      185   2139
# Epoch 14  Train Loss: 0.0147  Train Accuracy: 82.60%         Val Loss: 0.0148  Val Accuracy: 82.57%
#          fear  anger   sad  neutral  disgust  happy
# fear     2463     81    48      133       47     23
# anger     117   2176   135       78       41    248
# sad        51     47  2242      139       49    267
# neutral    90     62   154     2339       87     63
# disgust    33     16    34       84     2095    113
# happy      40    137   262       39      132   2183
# Epoch 15  Train Loss: 0.0141  Train Accuracy: 83.31%         Val Loss: 0.0144  Val Accuracy: 82.96%
#          fear  anger   sad  neutral  disgust  happy
# fear     2509     70    35      100       46     35
# anger     120   2259    84       54       41    237
# sad        53     93  2166       96       57    330
# neutral    94     79   143     2301       99     79
# disgust    19     29    16       80     2088    143
# happy      22    171   185       38      137   2240
# Epoch 16  Train Loss: 0.0136  Train Accuracy: 83.83%         Val Loss: 0.0144  Val Accuracy: 83.11%
#          fear  anger   sad  neutral  disgust  happy
# fear     2458     82    41      123       62     29
# anger     104   2271    93       49       54    224
# sad        49     82  2191       96       55    322
# neutral    99     73   173     2275      102     73
# disgust    13     23    22       71     2121    125
# happy      16    157   162       25      162   2271
# Epoch 17  Train Loss: 0.0132  Train Accuracy: 84.40%         Val Loss: 0.0141  Val Accuracy: 83.29%
#          fear  anger   sad  neutral  disgust  happy
# fear     2477     78    33      130       44     33
# anger     114   2245    84       72       31    249
# sad        55     68  2191      112       29    340
# neutral    80     72   141     2349       79     74
# disgust    19     30    29       82     2090    125
# happy      23    157   176       47      126   2264
# Epoch 18  Train Loss: 0.0129  Train Accuracy: 84.53%         Val Loss: 0.0142  Val Accuracy: 83.67%
#          fear  anger   sad  neutral  disgust  happy
# fear     2533     66    35       87       47     27
# anger     114   2230   101       57       47    246
# sad        41     67  2249      102       58    278
# neutral   104     78   152     2302       97     62
# disgust    31     16    16       72     2121    119
# happy      23    133   216       35      143   2243
# Epoch 19  Train Loss: 0.0127  Train Accuracy: 84.84%         Val Loss: 0.0139  Val Accuracy: 83.88%
#          fear  anger   sad  neutral  disgust  happy
# fear     2499     56    44      112       55     29
# anger     110   2182   133       59       62    249
# sad        41     55  2291      132       51    225
# neutral    83     48   144     2373      104     43
# disgust    18     10    21       73     2173     80
# happy      23    123   222       38      192   2195
# Epoch 20  Train Loss: 0.0124  Train Accuracy: 85.03%         Val Loss: 0.0138  Val Accuracy: 83.85%
#          fear  anger   sad  neutral  disgust  happy
# fear     2541     64    32       85       42     31
# anger      95   2285   123       77       28    187
# sad        46     70  2313      116       33    217
# neutral   106     73   140     2373       63     40
# disgust    29     38    36      127     2059     86
# happy      21    153   276       62      144   2137
# Epoch 21  Train Loss: 0.0121  Train Accuracy: 85.64%         Val Loss: 0.0138  Val Accuracy: 84.18%
#          fear  anger   sad  neutral  disgust  happy
# fear     2498     64    30      128       50     25
# anger     100   2262    99       77       41    216
# sad        37     77  2230      157       50    244
# neutral    62     54   107     2429       90     53
# disgust    27     16    26       74     2123    109
# happy      26    144   206       41      157   2219
# Epoch 22  Train Loss: 0.0117  Train Accuracy: 86.38%         Val Loss: 0.0137  Val Accuracy: 83.86%
#          fear  anger   sad  neutral  disgust  happy
# fear     2548     59    29       82       47     30
# anger     135   2264   120       55       31    190
# sad        54     75  2320       97       30    219
# neutral   113     55   151     2348       83     45
# disgust    32     24    49       70     2093    107
# happy      24    169   290       31      142   2137
# Epoch 23  Train Loss: 0.0115  Train Accuracy: 86.38%         Val Loss: 0.0135  Val Accuracy: 84.02%
#          fear  anger   sad  neutral  disgust  happy
# fear     2553     53    33       90       42     24
# anger     136   2250   117       77       38    177
# sad        51     67  2291      130       61    195
# neutral    97     60   105     2407       86     40
# disgust    36     27    28       79     2128     77
# happy      21    150   275       54      186   2107
# Epoch 24  Train Loss: 0.0110  Train Accuracy: 87.06%         Val Loss: 0.0138  Val Accuracy: 83.66%
#          fear  anger   sad  neutral  disgust  happy
# fear     2440     86    33      150       61     25
# anger      73   2201   122       97       58    244
# sad        40     62  2269      143       63    218
# neutral    54     53   101     2434      108     45
# disgust     9     19    29       66     2160     92
# happy      14    117   247       39      203   2173
# Epoch 25  Train Loss: 0.0108  Train Accuracy: 87.13%         Val Loss: 0.0133  Val Accuracy: 84.51%
#          fear  anger   sad  neutral  disgust  happy
# fear     2553     64    46       68       36     28
# anger     116   2251   116       48       29    235
# sad        37     61  2288       85       29    295
# neutral   108     61   154     2338       74     60
# disgust    22     32    41       89     2045    146
# happy      21    117   175       34      106   2340
# Epoch 26  Train Loss: 0.0108  Train Accuracy: 87.22%         Val Loss: 0.0133  Val Accuracy: 84.57%
#          fear  anger   sad  neutral  disgust  happy
# fear     2525     71    33      100       46     20
# anger      91   2239   128       61       31    245
# sad        34     40  2328      124       34    235
# neutral    83     67   142     2392       55     56
# disgust    16     21    47       91     2092    108
# happy      18    119   244       45      117   2250
# Epoch 27  Train Loss: 0.0104  Train Accuracy: 87.74%         Val Loss: 0.0130  Val Accuracy: 84.70%
#          fear  anger   sad  neutral  disgust  happy
# fear     2539     78    40       79       42     17
# anger     103   2261   130       54       45    202
# sad        48     55  2349       88       52    203
# neutral    90     74   153     2353       75     50
# disgust    26     21    42       78     2122     86
# happy      29    117   256       33      136   2222
# Epoch 28  Train Loss: 0.0103  Train Accuracy: 87.72%         Val Loss: 0.0131  Val Accuracy: 84.59%
#          fear  anger   sad  neutral  disgust  happy
# fear     2523     59    20      122       43     28
# anger      97   2293   111       66       30    198
# sad        47     77  2290      119       43    219
# neutral   103     65   115     2383       84     45
# disgust    21     20    31       76     2128     99
# happy      17    162   235       40      127   2212
# Epoch 29  Train Loss: 0.0100  Train Accuracy: 88.27%         Val Loss: 0.0129  Val Accuracy: 85.03%
#          fear  anger   sad  neutral  disgust  happy
# fear     2561     62    34       77       43     18
# anger     102   2348    78       43       32    192
# sad        55     83  2282       88       39    248
# neutral   101     72   152     2346       78     46
# disgust    24     35    42       70     2103    101
# happy      25    159   206       30      112   2261
# Epoch 30  Train Loss: 0.0099  Train Accuracy: 88.35%         Val Loss: 0.0130  Val Accuracy: 84.85%
#          fear  anger   sad  neutral  disgust  happy
# fear     2484     69    61      110       52     19
# anger      70   2289   129       44       38    225
# sad        27     60  2361       95       47    205
# neutral    64     58   154     2377       85     57
# disgust    16     23    36       80     2134     86
# happy      14    123   264       20      145   2227
# Epoch 31  Train Loss: 0.0098  Train Accuracy: 88.52%         Val Loss: 0.0130  Val Accuracy: 85.04%
#          fear  anger   sad  neutral  disgust  happy
# fear     2489     71    48       97       54     36
# anger      66   2282   121       44       43    239
# sad        25     53  2374       65       46    232
# neutral    58     67   181     2347       93     49
# disgust    16     25    29       63     2138    104
# happy      10    127   223       23      137   2273
# Epoch 32  Train Loss: 0.0094  Train Accuracy: 88.85%         Val Loss: 0.0128  Val Accuracy: 85.25%
#          fear  anger   sad  neutral  disgust  happy
# fear     2523     66    29       99       56     22
# anger      83   2253    81       72       48    258
# sad        29     49  2250      133       61    273
# neutral    72     49    98     2411      100     65
# disgust    15     16    16       64     2185     79
# happy      13    111   152       35      167   2315
# Epoch 33  Train Loss: 0.0095  Train Accuracy: 88.82%         Val Loss: 0.0127  Val Accuracy: 85.11%
#          fear  anger   sad  neutral  disgust  happy
# fear     2565     70    24       74       43     19
# anger      92   2309    93       54       34    213
# sad        55     82  2249      104       54    251
# neutral    70     62   106     2417       83     57
# disgust    29     23    24       76     2139     84
# happy      25    145   202       35      152   2234
# Epoch 34  Train Loss: 0.0090  Train Accuracy: 89.26%         Val Loss: 0.0127  Val Accuracy: 85.42%
#          fear  anger   sad  neutral  disgust  happy
# fear     2546     71    20       88       44     26
# anger      74   2355    63       62       41    200
# sad        43     97  2259      100       50    246
# neutral    77     80   102     2388       91     57
# disgust    20     21    20       68     2141    105
# happy      18    147   162       34      156   2276
# Epoch 35  Train Loss: 0.0091  Train Accuracy: 89.23%         Val Loss: 0.0126  Val Accuracy: 85.44%
#          fear  anger   sad  neutral  disgust  happy
# fear     2536     72    23       96       44     24
# anger      79   2359    77       57       29    194
# sad        38     90  2266      113       49    239
# neutral    71     79    94     2426       80     45
# disgust    16     19    24       91     2158     67
# happy      22    163   179       37      169   2223
# Epoch 36  Train Loss: 0.0089  Train Accuracy: 89.64%         Val Loss: 0.0128  Val Accuracy: 85.38%
#          fear  anger   sad  neutral  disgust  happy
# fear     2530     67    23       96       51     28
# anger      90   2308    83       54       35    225
# sad        37     71  2257      124       48    258
# neutral    91     74   100     2393       89     48
# disgust    21     19    28       61     2159     87
# happy      17    124   173       30      138   2311
# Epoch 37  Train Loss: 0.0087  Train Accuracy: 89.77%         Val Loss: 0.0123  Val Accuracy: 86.03%
#          fear  anger   sad  neutral  disgust  happy
# fear     2562     60    39       73       40     21
# anger     103   2309   115       48       37    183
# sad        36     56  2358       96       48    201
# neutral    75     51   117     2429       79     44
# disgust    25     23    24       66     2152     85
# happy      19    114   223       43      140   2254
# Epoch 38  Train Loss: 0.0086  Train Accuracy: 89.92%         Val Loss: 0.0129  Val Accuracy: 85.21%
#          fear  anger   sad  neutral  disgust  happy
# fear     2464     73    35      121       58     44
# anger      68   2302    94       76       38    217
# sad        31     63  2323       92       46    240
# neutral    72     67   120     2401       83     52
# disgust    11     15    24       86     2158     81
# happy      12    126   193       41      139   2282
# Epoch 39  Train Loss: 0.0083  Train Accuracy: 90.41%         Val Loss: 0.0128  Val Accuracy: 85.62%
#          fear  anger   sad  neutral  disgust  happy
# fear     2510     89    46       78       42     30
# anger      59   2330   119       40       33    214
# sad        23     54  2431       69       38    180
# neutral    74     69   165     2359       76     52
# disgust    25     22    36       76     2119     97
# happy      13    114   266       32      120   2248
# Epoch 40  Train Loss: 0.0082  Train Accuracy: 90.52%         Val Loss: 0.0130  Val Accuracy: 85.53%
#          fear  anger   sad  neutral  disgust  happy
# fear     2539     76    31       77       39     33
# anger      76   2369    90       30       36    194
# sad        38     65  2279       80       65    268
# neutral    83     72   146     2313      114     67
# disgust    23     27    23       43     2158    101
# happy      16    140   167       16      129   2325
# Epoch 41  Train Loss: 0.0083  Train Accuracy: 90.14%         Val Loss: 0.0127  Val Accuracy: 85.66%
#          fear  anger   sad  neutral  disgust  happy
# fear     2548     55    33       93       39     27
# anger      82   2279   130       66       29    209
# sad        37     51  2354      108       36    209
# neutral    61     50   112     2467       48     57
# disgust    21     19    37      106     2091    101
# happy      16    111   245       40      117   2264
# Epoch 42  Train Loss: 0.0075  Train Accuracy: 91.20%         Val Loss: 0.0118  Val Accuracy: 86.76%
#          fear  anger   sad  neutral  disgust  happy
# fear     2622     48    19       56       33     17
# anger     104   2346    69       54       32    190
# sad        42     68  2322       87       49    227
# neutral    98     58   111     2402       74     52
# disgust    29     23    26       61     2154     82
# happy      18    132   155       27      123   2338
# Epoch 43  Train Loss: 0.0074  Train Accuracy: 91.41%         Val Loss: 0.0120  Val Accuracy: 86.62%
#          fear  anger   sad  neutral  disgust  happy
# fear     2568     66    17       72       48     24
# anger      80   2422    63       44       24    162
# sad        46     85  2296       99       41    228
# neutral    72     66    90     2434       85     48
# disgust    17     34    21       70     2146     87
# happy      17    175   150       26      131   2294
# Epoch 44  Train Loss: 0.0071  Train Accuracy: 91.76%         Val Loss: 0.0119  Val Accuracy: 86.61%
#          fear  anger   sad  neutral  disgust  happy
# fear     2583     72    22       60       37     21
# anger      76   2382    71       50       38    178
# sad        50     68  2316       98       36    227
# neutral    78     77    85     2432       74     49
# disgust    22     27    24       68     2148     86
# happy      13    141   177       27      137   2298
# Epoch 45  Train Loss: 0.0069  Train Accuracy: 91.93%         Val Loss: 0.0120  Val Accuracy: 86.78%
#          fear  anger   sad  neutral  disgust  happy
# fear     2573     55    32       67       49     19
# anger      85   2350    79       49       33    199
# sad        26     67  2321       93       45    243
# neutral    69     62   102     2437       76     49
# disgust    14     15    19       68     2171     88
# happy      20    126   162       28      122   2335
# Epoch 46  Train Loss: 0.0069  Train Accuracy: 91.89%         Val Loss: 0.0119  Val Accuracy: 86.78%
#          fear  anger   sad  neutral  disgust  happy
# fear     2574     65    22       68       44     22
# anger      74   2418    77       38       35    153
# sad        27     95  2292      112       52    217
# neutral    67     75    80     2442       84     47
# disgust    10     24    21       55     2190     75
# happy      10    169   174       24      145   2271
# Epoch 47  Train Loss: 0.0063  Train Accuracy: 92.77%         Val Loss: 0.0118  Val Accuracy: 86.85%
#          fear  anger   sad  neutral  disgust  happy
# fear     2548     58    26       99       45     19
# anger      63   2367    92       66       28    179
# sad        29     68  2314      126       49    209
# neutral    51     55    83     2492       69     45
# disgust    12     19    20       82     2164     78
# happy      10    142   187       29      112   2313
# Epoch 48  Train Loss: 0.0063  Train Accuracy: 92.68%         Val Loss: 0.0121  Val Accuracy: 86.90%
#          fear  anger   sad  neutral  disgust  happy
# fear     2574     46    19       84       49     23
# anger      72   2336    70       68       43    206
# sad        44     68  2280      104       56    243
# neutral    59     44    83     2461       96     52
# disgust    10     14    19       52     2225     55
# happy      10    124   151       27      151   2330
# Epoch 49  Train Loss: 0.0063  Train Accuracy: 92.66%         Val Loss: 0.0116  Val Accuracy: 87.12%
#          fear  anger   sad  neutral  disgust  happy
# fear     2521    105    30       83       35     21
# anger      54   2454    82       26       23    156
# sad        23     82  2385       67       39    199
# neutral    55     85   118     2425       65     47
# disgust    13     29    24       64     2149     96
# happy      11    177   184       17       95   2309
# Epoch 50  Train Loss: 0.0060  Train Accuracy: 93.16%         Val Loss: 0.0115  Val Accuracy: 87.25%
#          fear  anger   sad  neutral  disgust  happy
# fear     2589     51    26       68       42     19
# anger      81   2373    89       43       33    176
# sad        43     59  2364       86       36    207
# neutral    67     60   115     2442       65     46
# disgust    21     19    27       65     2169     74
# happy      14    122   194       22      114   2327
# Epoch 51  Train Loss: 0.0060  Train Accuracy: 93.05%         Val Loss: 0.0117  Val Accuracy: 87.18%
#          fear  anger   sad  neutral  disgust  happy
# fear     2593     56    19       70       41     16
# anger      74   2374    96       49       31    171
# sad        40     59  2330       95       44    227
# neutral    71     47   109     2458       70     40
# disgust    20     16    23       68     2172     76
# happy      15    128   179       27      119   2325
# Epoch 52  Train Loss: 0.0058  Train Accuracy: 93.23%         Val Loss: 0.0117  Val Accuracy: 87.47%
#          fear  anger   sad  neutral  disgust  happy
# fear     2584     53    30       73       34     21
# anger      65   2347    97       45       27    214
# sad        23     44  2399       74       45    210
# neutral    64     46   124     2444       67     50
# disgust    15     16    28       61     2173     82
# happy      11     95   187       19      129   2352
# Epoch 53  Train Loss: 0.0059  Train Accuracy: 93.07%         Val Loss: 0.0115  Val Accuracy: 87.30%
#          fear  anger   sad  neutral  disgust  happy
# fear     2563     58    22       82       52     18
# anger      63   2365    84       58       34    191
# sad        35     62  2320      112       39    227
# neutral    57     47    80     2500       63     48
# disgust    11     18    23       67     2172     84
# happy      14    119   153       31      124   2352
# Epoch 54  Train Loss: 0.0058  Train Accuracy: 93.18%         Val Loss: 0.0117  Val Accuracy: 86.91%
#          fear  anger   sad  neutral  disgust  happy
# fear     2587     58    27       68       40     15
# anger      78   2381    87       61       35    153
# sad        40     62  2349      106       48    190
# neutral    81     53    90     2462       66     43
# disgust    15     20    28       76     2168     68
# happy      10    153   214       36      119   2261
# Epoch 55  Train Loss: 0.0055  Train Accuracy: 93.53%         Val Loss: 0.0115  Val Accuracy: 87.66%
#          fear  anger   sad  neutral  disgust  happy
# fear     2577     65    21       70       39     23
# anger      53   2431    79       36       31    165
# sad        22     66  2360       74       36    237
# neutral    59     71   103     2435       70     57
# disgust    11     25    29       59     2150    101
# happy      12    140   152       14       97   2378
# Epoch 56  Train Loss: 0.0054  Train Accuracy: 93.75%         Val Loss: 0.0116  Val Accuracy: 87.45%
#          fear  anger   sad  neutral  disgust  happy
# fear     2578     63    23       67       40     24
# anger      66   2357   101       46       37    188
# sad        38     64  2359       88       51    195
# neutral    67     54    91     2473       72     38
# disgust    15     14    21       63     2198     64
# happy       9     99   189       28      137   2331
# Epoch 57  Train Loss: 0.0053  Train Accuracy: 93.94%         Val Loss: 0.0115  Val Accuracy: 87.48%
#          fear  anger   sad  neutral  disgust  happy
# fear     2599     59    28       50       42     17
# anger      78   2391    96       33       36    161
# sad        31     60  2420       74       40    170
# neutral    70     65   119     2423       71     47
# disgust    12     18    32       59     2186     68
# happy      12    133   213       21      131   2283
# Epoch 58  Train Loss: 0.0053  Train Accuracy: 94.00%         Val Loss: 0.0115  Val Accuracy: 87.71%
#          fear  anger   sad  neutral  disgust  happy
# fear     2567     65    33       67       42     21
# anger      54   2408    96       43       31    163
# sad        25     49  2408       76       41    196
# neutral    48     54   117     2451       77     48
# disgust     7     21    28       57     2175     87
# happy       7    124   213       19      100   2330
# Epoch 59  Train Loss: 0.0052  Train Accuracy: 94.02%         Val Loss: 0.0115  Val Accuracy: 87.62%
#          fear  anger   sad  neutral  disgust  happy
# fear     2598     43    23       70       41     20
# anger      80   2332    88       64       31    200
# sad        33     48  2343      114       38    219
# neutral    52     43    90     2500       60     50
# disgust    14     15    21       70     2169     86
# happy      14     95   165       27      110   2382
# Epoch 60  Train Loss: 0.0052  Train Accuracy: 93.95%         Val Loss: 0.0116  Val Accuracy: 87.77%
#          fear  anger   sad  neutral  disgust  happy
# fear     2537     66    38       80       44     30
# anger      64   2390    86       47       32    176
# sad        16     52  2422       72       40    193
# neutral    48     49   112     2467       74     45
# disgust    12     18    23       69     2172     81
# happy       9    113   186       23      102   2360
# Epoch 61  Train Loss: 0.0051  Train Accuracy: 94.16%         Val Loss: 0.0116  Val Accuracy: 87.82%
#          fear  anger   sad  neutral  disgust  happy
# fear     2588     62    26       51       41     27
# anger      61   2384    83       43       28    196
# sad        28     55  2393       64       38    217
# neutral    62     58   123     2420       78     54
# disgust     8     16    25       55     2183     88
# happy      10    114   173       17       90   2389
# Epoch 62  Train Loss: 0.0051  Train Accuracy: 94.20%         Val Loss: 0.0116  Val Accuracy: 87.85%
#          fear  anger   sad  neutral  disgust  happy
# fear     2570     61    31       67       45     21
# anger      54   2428    80       28       30    175
# sad        23     49  2381       67       37    238
# neutral    57     60   121     2408       90     59
# disgust    10     18    26       50     2178     93
# happy      10    123   150       12      102   2396
# Epoch 63  Train Loss: 0.0049  Train Accuracy: 94.36%         Val Loss: 0.0113  Val Accuracy: 87.97%
#          fear  anger   sad  neutral  disgust  happy
# fear     2595     47    20       70       43     20
# anger      79   2373    82       41       33    187
# sad        28     50  2397       77       37    206
# neutral    55     52    95     2469       75     49
# disgust    10     12    24       61     2190     78
# happy       9    113   180       17      116   2358
# Epoch 64  Train Loss: 0.0048  Train Accuracy: 94.54%         Val Loss: 0.0114  Val Accuracy: 88.30%
#          fear  anger   sad  neutral  disgust  happy
# fear     2602     54    19       61       36     23
# anger      67   2401    95       41       25    166
# sad        26     51  2421       77       40    180
# neutral    61     45   103     2463       73     50
# disgust    13     14    27       55     2196     70
# happy       9    112   194       23      102   2353
# Epoch 65  Train Loss: 0.0047  Train Accuracy: 94.58%         Val Loss: 0.0116  Val Accuracy: 87.94%
#          fear  anger   sad  neutral  disgust  happy
# fear     2598     54    23       56       43     21
# anger      72   2370    96       35       38    184
# sad        34     53  2404       77       48    179
# neutral    63     47   108     2449       83     45
# disgust    10     14    19       51     2221     60
# happy      10    106   201       16      125   2335
# Epoch 66  Train Loss: 0.0048  Train Accuracy: 94.51%         Val Loss: 0.0113  Val Accuracy: 88.00%
#          fear  anger   sad  neutral  disgust  happy
# fear     2561     58    22       89       39     26
# anger      60   2393    76       49       29    188
# sad        22     55  2342       92       36    248
# neutral    43     51    86     2504       59     52
# disgust     7     15    22       68     2162    101
# happy       6    118   132       29       84   2424
# Epoch 67  Train Loss: 0.0048  Train Accuracy: 94.46%         Val Loss: 0.0113  Val Accuracy: 88.13%
#          fear  anger   sad  neutral  disgust  happy
# fear     2589     59    15       76       38     18
# anger      60   2418    65       47       31    174
# sad        34     65  2345       98       42    211
# neutral    53     51    78     2504       62     47
# disgust    12     18    21       75     2177     72
# happy       7    116   164       32       99   2375
# Epoch 68  Train Loss: 0.0047  Train Accuracy: 94.64%         Val Loss: 0.0113  Val Accuracy: 87.94%
#          fear  anger   sad  neutral  disgust  happy
# fear     2594     59    21       56       37     28
# anger      62   2421    79       39       21    173
# sad        30     67  2394       70       34    200
# neutral    58     69   106     2442       65     55
# disgust    11     18    28       62     2153    103
# happy       9    125   183       21       83   2372
# Epoch 69  Train Loss: 0.0047  Train Accuracy: 94.67%         Val Loss: 0.0114  Val Accuracy: 87.94%
#          fear  anger   sad  neutral  disgust  happy
# fear     2578     63    23       67       39     25
# anger      57   2413    83       39       25    178
# sad        23     61  2411       75       37    188
# neutral    53     63   107     2447       75     50
# disgust     9     20    23       58     2165    100
# happy      12    120   193       17       88   2363
# Epoch 70  Train Loss: 0.0046  Train Accuracy: 94.74%         Val Loss: 0.0114  Val Accuracy: 88.08%
#          fear  anger   sad  neutral  disgust  happy
# fear     2599     57    18       56       42     23
# anger      66   2420    78       37       25    169
# sad        35     58  2378       74       34    216
# neutral    71     60    99     2453       63     49
# disgust     9     20    26       63     2180     77
# happy      10    142   159       20       93   2369

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
loss_plot = [val_loss, train_loss]
acc_plot = [val_acc, train_acc]


def draw(acc_plot, loss_plot, hist_lr=None):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 5))
    for line in acc_plot:
        ax1.plot(range(len(line)), line)
    ax1.set_xlabel("Epoch #", fontsize=8)
    ax1.set_ylabel("Accuracy", fontsize=8)
    ax1.set_title("Model Accuracy split-0")
    for line in loss_plot:
        ax2.plot(range(len(line)), line)
    ax2.set_xlabel("Epoch #", fontsize=8)
    ax2.set_ylabel("Loss", fontsize=8)
    ax2.set_title("Model Loss split-0")
    labels1 = ["val_acc", "train_acc"]
    labels2 = ["val_loss", "train_loss"]
    fig.legend(labels1, loc="upper left")
    fig.legend(labels2, loc="upper right")


draw(acc_plot, loss_plot)

# %%
import matplotlib.pyplot as plt
import numpy as np

# 範例數據
x = np.linspace(0, 200, 500)  # 0~200
y = np.sin(x/10)

# 畫圖
plt.plot(x, y)
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Example Plot")

# 限制 x 軸到 0~100
plt.xlim(0, 100)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import matplotlib.pyplot as plt
#       2 import numpy as np
#       4 # 範例數據
#
# ModuleNotFoundError: No module named 'matplotlib'
